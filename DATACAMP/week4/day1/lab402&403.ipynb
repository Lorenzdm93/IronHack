# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import math
import warnings
warnings.filterwarnings('ignore')
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# ...

# %%
data.columns = [val.lower().replace(' ','_') for val in data.columns] #snake case
data.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
cat = data.select_dtypes(include=np.object)
num = data.select_dtypes(include = np.number)

# %%
correlations_matrix= num.corr()
mask = np.zeros_like(correlations_matrix)
mask[np.triu_indices_from(mask)] = True
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(correlations_matrix, mask=mask, annot=True)
plt.show()

# %%
data=data.drop(['customer'], axis=1)

# %%
data=data.drop(['effective_to_date'], axis=1)

# %%
data.head()
# Out:
#         state  customer_lifetime_value response  coverage education  \
# 0  Washington              2763.519279       No     Basic  Bachelor
# 1     Arizona              6979.535903       No  Extended  Bachelor
# 2      Nevada             12887.431650       No   Premium  Bachelor
# 3  California              7645.861827       No     Basic  Bachelor
# 4  Washington              2813.692575       No     Basic  Bachelor
#
#   employmentstatus gender  income location_code marital_status  \
# 0         Employed      F   56274      Suburban        Married
# 1       Unemployed      F       0      Suburban         Single
# 2         Employed      F   48767      Suburban        Married
# 3       Unemployed      M       0      Suburban        Married
# 4         Employed      M   43836         Rural         Single
#
#    monthly_premium_auto  months_since_last_claim  \
# 0                    69                       32
# 1                    94                       13
# ...

# %%
#getting a visual on categorticals (also barplots).
#if I have cat over target you can do boxplot or barplot (if target is cat, include as "hue", if its numerical u do a boxplot)
#visualize numericals with hist or distplot
#num on num with scatter

data_cats_cols = cat.columns
fig,axs = plt.subplots(ncols=7, nrows=3, figsize =(10, 30))
plt.subplots_adjust(right=1.5)

for i, feature in enumerate(data_cats_cols, 1):
    plt.subplot(7, 3, i)
    sns.countplot(x = feature, data = cat) #'hue = "target"' goes here between x and data
plt.show()

# %%
num.head()
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44
#
#    number_of_open_complaints  number_of_policies  total_claim_amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935
# ...

# %%
#visualizing numericals overview

for i in num.columns:
    sns.displot(num[i])
plt.show()

# %%
num.head(2)
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                       32                              5
# 1                       13                             42
#
#    number_of_open_complaints  number_of_policies  total_claim_amount
# 0                          0                   1          384.811147
# 1                          0                   8         1131.464935

# %%
f, ax = plt.subplots(1, 3, figsize=(12,5))

for i, col in enumerate(num.iloc[:,0:3]):
    sns.boxplot(data = num[col], ax = ax[i])
    ax[i].set_title(col, fontsize = 14)

plt.show()
