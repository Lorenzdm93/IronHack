# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import math
import warnings
warnings.filterwarnings('ignore')
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sucesses=[10,100,1000,10000,100000,1000000]

for i in sucesses:
    pd.DataFrame(np.random.binomial(n=i, p=0.5, size=1000000)).hist()

# %%
for i in sucesses:
    pd.DataFrame(np.random.binomial(n=i, p=0.5, size=1000000))

# %%
p=[0.01, 0.1, 0.25, 0.5, 0.75, 0.9, 0.99]
n = 100 
size = 1000

for i in p: 
    plt.figure() 
    x = np.random.binomial(n=100, p=i, size=1000) 
    sns.distplot(x)

plt.show()

# %% [markdown]
# because q=1-p
