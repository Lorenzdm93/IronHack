# %% [markdown]
# # What's an API (Python) Wrapper?

# %% [markdown]
# Functions of a wrapper:
# * Converts data into a compatible format for us, ready to use in Python (Formatting)
# * It helps you simplify a complex entity or makes a program perform complicated tasks easily (Generalizing)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_id = input("input cliend id") #de9b363a48b943c08984ea56c21bf873
client_secret = input('input client ') #76e5fbd4c8044d2aa25d12b5dfe7b45a
# Out:
# input cliend idde9b363a48b943c08984ea56c21bf873
# input client 76e5fbd4c8044d2aa25d12b5dfe7b45a

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id,
                                                           client_secret=client_secret))

# %%
sp.search(q='Tupac', limit=50)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Tupac&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4r63FhuTkUYltbVAg5TQnk'},
#        'href': 'https://api.spotify.com/v1/artists/4r63FhuTkUYltbVAg5TQnk',
#        'id': '4r63FhuTkUYltbVAg5TQnk',
#        'name': 'DaBaby',
#        'type': 'artist',
#        'uri': 'spotify:artist:4r63FhuTkUYltbVAg5TQnk'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BG',
#       'BH',
#       'BI',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
# ...

# %%
variable=sp.search(q='Ghetto Gospel', limit=50)

# %%
variable['tracks']['items'][0]['id']
# Out:
# '7jLbTp3qZzah9kMIdW8e5M'

# %%
lis=sp.audio_features('7jLbTp3qZzah9kMIdW8e5M')

# %%
lis
# Out:
# [{'danceability': 0.794,
#   'energy': 0.614,
#   'key': 5,
#   'loudness': -5.352,
#   'mode': 0,
#   'speechiness': 0.0467,
#   'acousticness': 0.0964,
#   'instrumentalness': 0,
#   'liveness': 0.0788,
#   'valence': 0.663,
#   'tempo': 80.569,
#   'type': 'audio_features',
#   'id': '7jLbTp3qZzah9kMIdW8e5M',
#   'uri': 'spotify:track:7jLbTp3qZzah9kMIdW8e5M',
#   'track_href': 'https://api.spotify.com/v1/tracks/7jLbTp3qZzah9kMIdW8e5M',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7jLbTp3qZzah9kMIdW8e5M',
#   'duration_ms': 238053,
#   'time_signature': 4}]

# %%
l=['acousticness', 'danceability', 'duration_ms', 'energy',
       'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
       'speechiness', 'tempo', 'time_signature', 'valence']

# %%
acousticness=lis[0]['acousticness']
print(acousticness)
# Out:
# 0.0964

# %%
danceability=lis[0]['danceability']
print(danceability)
# Out:
# 0.794

# %%
duration_ms=lis[0]['duration_ms']
print(duration_ms)
# Out:
# 238053

# %%
energy=lis[0]['energy']
print(energy)
# Out:
# 0.614

# %%
instrumentalness=lis[0]['instrumentalness']
print(instrumentalness)
# Out:
# 0

# %%
key=lis[0]['key']
print(key)
# Out:
# 5

# %%
liveness=lis[0]['liveness']
print(liveness)
# Out:
# 0.0788

# %%
loudness=lis[0]['loudness']
print(loudness)
# Out:
# -5.352

# %%
mode=lis[0]['mode']
print(mode)
# Out:
# 0

# %%
speechiness=lis[0]['speechiness']
print(speechiness)
# Out:
# 0.0467

# %%
tempo=lis[0]['tempo']
print(tempo)
# Out:
# 80.569

# %%
time_signature=lis[0]['time_signature']
print(time_signature)
# Out:
# 4

# %%
valence=lis[0]['valence']
print(valence)
# Out:
# 0.663

# %%
# let's store that in results
results = sp.search(q='Tupac', limit=50)

# %%
results['tracks']
# Out:
# {'href': 'https://api.spotify.com/v1/search?query=Tupac&type=track&offset=0&limit=50',
#  'items': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4r63FhuTkUYltbVAg5TQnk'},
#       'href': 'https://api.spotify.com/v1/artists/4r63FhuTkUYltbVAg5TQnk',
#       'id': '4r63FhuTkUYltbVAg5TQnk',
#       'name': 'DaBaby',
#       'type': 'artist',
#       'uri': 'spotify:artist:4r63FhuTkUYltbVAg5TQnk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BG',
#      'BH',
#      'BI',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
# ...

# %%
artist_list = ['Ozzy Osbourne', 'Ariana Grande', 'Queen']
#result_list = [sp.search(q=artist, limit=50) for artist in artist_list]

def artist_to_json(artists):
    return {artist:sp.search(q=artist, limit=50) for artist in artists}

results = artist_to_json(artist_list)

# %%
results.keys()
# Out:
# dict_keys(['Ozzy Osbourne', 'Ariana Grande', 'Queen'])

# %%
results['Queen']
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Queen&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cFrymmkijnjDg9SS92EPM'},
#        'href': 'https://api.spotify.com/v1/artists/2cFrymmkijnjDg9SS92EPM',
#        'id': '2cFrymmkijnjDg9SS92EPM',
#        'name': 'blackbear',
#        'type': 'artist',
#        'uri': 'spotify:artist:2cFrymmkijnjDg9SS92EPM'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
# ...

# %%
results['Queen']['tracks']['href']    #query that was used to search
# Out:
# 'https://api.spotify.com/v1/search?query=Queen&type=track&offset=0&limit=50'

# %%
results['Queen']['tracks']['items']   # a list of tracks that were found for the search term Queen
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cFrymmkijnjDg9SS92EPM'},
#      'href': 'https://api.spotify.com/v1/artists/2cFrymmkijnjDg9SS92EPM',
#      'id': '2cFrymmkijnjDg9SS92EPM',
#      'name': 'blackbear',
#      'type': 'artist',
#      'uri': 'spotify:artist:2cFrymmkijnjDg9SS92EPM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
# ...

# %%
results['Queen']['tracks'].keys()    # check what kind of keys are in ['tracks']
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
results['Queen']['tracks']['next']   # link to the next page (in this case 50 tracks)
# Out:
# 'https://api.spotify.com/v1/search?query=Queen&type=track&offset=50&limit=50'

# %%
results['Queen']['tracks']['offset']  # starting point
# Out:
# 0

# %%
results['Queen']['tracks']['previous']  # Previous search

# %%
results['Queen']['tracks']['total']    # How many matches has our search generated?
# Out:
# 150361

# %%
len(results['Queen']['tracks']['items'])
# Out:
# 50

# %%
results['Queen']['tracks']['items']
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cFrymmkijnjDg9SS92EPM'},
#      'href': 'https://api.spotify.com/v1/artists/2cFrymmkijnjDg9SS92EPM',
#      'id': '2cFrymmkijnjDg9SS92EPM',
#      'name': 'blackbear',
#      'type': 'artist',
#      'uri': 'spotify:artist:2cFrymmkijnjDg9SS92EPM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
# ...

# %%
results['Queen']['tracks']['items'][0]   # index 0, because we want to inspect the first song
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cFrymmkijnjDg9SS92EPM'},
#     'href': 'https://api.spotify.com/v1/artists/2cFrymmkijnjDg9SS92EPM',
#     'id': '2cFrymmkijnjDg9SS92EPM',
#     'name': 'blackbear',
#     'type': 'artist',
#     'uri': 'spotify:artist:2cFrymmkijnjDg9SS92EPM'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
# ...

# %%
results['Queen']['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
results['Queen']['tracks']['items'][0]['name']   # name of the song of index 0
# Out:
# 'queen of broken hearts'

# %%
# maybe get 'popularity' and 'explicit', as features?

# %%
results['Queen']['tracks']['items'][0]['popularity']    # popularity, ranges from 0 to 100 (?), where 100 is
                                                            # maximum
# Out:
# 73

# %%
results['Queen']['tracks']['items'][0]['uri']
# Out:
# 'spotify:track:1HKl3RJInVzf5ObVnM644j'

# %%
# spotify:track:4GbYLpSqf2Trkwqgb7p1os

# %%
results['Queen']['tracks']
# Out:
# {'href': 'https://api.spotify.com/v1/search?query=Queen&type=track&offset=0&limit=50',
#  'items': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cFrymmkijnjDg9SS92EPM'},
#       'href': 'https://api.spotify.com/v1/artists/2cFrymmkijnjDg9SS92EPM',
#       'id': '2cFrymmkijnjDg9SS92EPM',
#       'name': 'blackbear',
#       'type': 'artist',
#       'uri': 'spotify:artist:2cFrymmkijnjDg9SS92EPM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DM',
# ...

# %% [markdown]
# # 8.05 Activity 2
#
# Create a function to extract all the artists of a song and another function to extract all the artists IDs from a song.
#
# Input: track dictionary, like
#
# ```python
#
# results['Queen']['tracks']
#
# ```
#
# which comes in the form of
#
# ```python
#
# {'href': 'https://api.spotify.com/v1/search?query=Queen&type=track&offset=0&limit=50',
#  'items': [{'album': {'album_type': 'album',
# 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cFrymmkijnjDg9SS92EPM'},
#   'href': 'https://api.spotify.com/v1/artists/2cFrymmkijnjDg9SS92EPM',
#   'id': '2cFrymmkijnjDg9SS92EPM',
#   'name': 'blackbear',
#   'type': 'artist',
#   'uri': 'spotify:artist:2cFrymmkijnjDg9SS92EPM'}],
# 'available_markets': ['AD',
#  'AE',
#  'AL',
#  ...
#
#  ```
#
# Output: List of artists/List of IDs

# %% [markdown]
# #### Solution:
#
# ```python
# def get_artists_from_track(track):
#     return[artist["name"] for artist in track["artists"]]
#
# #--------------------------------------------------------------------
#
# def get_artists_ids_from_track(track):
#     return[artist["id"] for artist in track["artists"]]
# ```

# %% [markdown]
# # Let's continue with lecture

# %%
playlist = sp.user_playlist_tracks("spotify", "4rnleEAOdmFAbRcNCgZMpY")

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist['total']
# Out:
# 5198

# %%
len(playlist['items'])
# Out:
# 100

# %%
# Function:
        # input: username, playlist_id
        # output: ALL the songs, not just 100
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username, playlist_id)
    tracks = results['items']
    while results['next']:
        # print(results['next'])
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
# now let'S store all the tracks in a variable
all_tracks = get_playlist_tracks('spotify', "4rnleEAOdmFAbRcNCgZMpY")
len(get_playlist_tracks('spotify', "4rnleEAOdmFAbRcNCgZMpY"))
# Out:
# 5198

# %% [markdown]
# # What we want: Get all the (unique) artists from a playlist!

# %%
# we need this puzzle piece for our function
# this gets us the artist ids from one track
def get_artists_ids_from_track(track):
    return[artist["id"] for artist in track["artists"]]

# another puzzle piece
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]




# THIS IS OUR FUNCTION THAT SHOULD DO THE JOB
def get_artists_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks('spotify', playlist_id)
    
    # should return all the artists
        # but they should be unique! so we make use of set()
    
    return set([artist for subset in [get_artists_from_track(track['track']) for track in tracks_from_playlist] for artist in subset])

# %%
set([1,2,3,4,4,4,5,6])
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
playlist['next']
# Out:
# 'https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=100&limit=100&additional_types=track'

# %%
tracks_from_playlist = get_playlist_tracks('spotify', "4rnleEAOdmFAbRcNCgZMpY")

# %%
[get_artists_from_track(track['track']) for track in tracks_from_playlist]
# Out:
# [['Hozier'],
#  ['Mike Posner', 'Gigamesh'],
#  ['Tyler, The Creator', 'Kali Uchis'],
#  ['Bastille'],
#  ['Shakira', 'Wyclef Jean'],
#  ['The Script', 'will.i.am'],
#  ['Otto Knows', 'Avicii'],
#  ['Selena Gomez'],
#  ['Taio Cruz'],
#  ['Mohombi'],
#  ['Lucenzo', 'Don Omar'],
#  ['Cheek', 'Yasmine Yamajako'],
#  ['Flo Rida'],
#  ['Avril Lavigne'],
#  ['Justin Bieber', 'Ludacris'],
#  ['Flo Rida'],
#  ['Mohombi', 'Nicole Scherzinger'],
#  ['Justin Bieber'],
#  ['Pikku G', 'Sophie'],
#  ['Swedish House Mafia', 'John Martin'],
#  ['Macklemore & Ryan Lewis'],
#  ['David Guetta', 'Sia'],
#  ['Imagine Dragons'],
#  ['Flo Rida'],
#  ['Calvin Harris', 'Ellie Goulding'],
#  ['Pitbull', 'Kesha'],
#  ['will.i.am', 'Britney Spears'],
#  ['Avicii'],
#  ['Macklemore & Ryan Lewis', 'Wanz'],
#  ['David Guetta'],
#  ['The Script'],
#  ['Flo Rida'],
#  ['OneRepublic'],
#  ['PSY'],
#  ['Pitbull', 'Christina Aguilera'],
#  ['FRENSHIP', 'Emily Warren'],
#  ['Tungevaag', 'Raaban'],
#  ['Leona Lewis'],
# ...

# %%
import numpy as np

# %%
# remember yesterday:
a = np.array([[0.84062117, 0.48006452, 0.7876326 , 0.77109654],
       [0.44409793, 0.09014516, 0.81835917, 0.87645456],
       [0.7066597 , 0.09610873, 0.41247947, 0.57433389],
       [0.29960807, 0.42315023, 0.34452557, 0.4751035 ],
       [0.17003563, 0.46843998, 0.92796258, 0.69814654],
       [0.41290051, 0.19561071, 0.16284783, 0.97016248],
       [0.71725408, 0.87702738, 0.31244595, 0.76615487],
       [0.20754036, 0.57871812, 0.07214068, 0.40356048],
       [0.12149553, 0.53222417, 0.9976855 , 0.12536346],
       [0.80930099, 0.50962849, 0.94555126, 0.33364763]])

# Nested list:
[number for list_ in a for number in list_]

# same like this nested for loop
for list_ in a:
    for number in list_:
        print(number)
# Out:
# 0.84062117
# 0.48006452
# 0.7876326
# 0.77109654
# 0.44409793
# 0.09014516
# 0.81835917
# 0.87645456
# 0.7066597
# 0.09610873
# 0.41247947
# 0.57433389
# 0.29960807
# 0.42315023
# 0.34452557
# 0.4751035
# 0.17003563
# 0.46843998
# 0.92796258
# 0.69814654
# 0.41290051
# 0.19561071
# 0.16284783
# 0.97016248
# 0.71725408
# 0.87702738
# 0.31244595
# 0.76615487
# 0.20754036
# 0.57871812
# 0.07214068
# 0.40356048
# 0.12149553
# 0.53222417
# 0.9976855
# 0.12536346
# 0.80930099
# 0.50962849
# 0.94555126
# 0.33364763

# %%
# We want to flatten the nested list of artists! We can do that with a nested list comprehension
set([artist for subset in [get_artists_from_track(track['track']) for track in tracks_from_playlist] for artist in subset])

# copy past this expression to our return to our function that should do the job
# Out:
# {'',
#  'Bonnie Tyler',
#  'Megan Thee Stallion',
#  'Roy English',
#  'Tinie Tempah',
#  'TobyMac',
#  'Brendon Urie',
#  'ZHU',
#  'Mally Mall',
#  'Chrishan',
#  'OG Ulla-Maija',
#  'Shelley FKA DRAM',
#  'Sebastian Ingrosso',
#  'Sweet Baby May',
#  'Shaggy',
#  'Setä Tamu',
#  'Ape Drums',
#  'Alis',
#  'Tina Turner',
#  'Dingo',
#  'PastoriPike',
#  'Solo Lucci',
#  'Musta-Lista',
#  'Wintertime',
#  'Villayn',
#  'Elonkerjuu',
#  'Tre Coast',
#  'Martti Vainaa',
#  'Zion & Lennox',
#  'Kid Travis',
#  'Ray J',
#  'Heikki Kuula',
#  'Ricky Martin',
#  'Showtek',
#  'Thomas Jack',
#  'SIDEPIECE',
#  'Sonique',
#  't.A.T.u.',
#  '112',
#  'Savage Ga$p',
#  'Tham Sway',
#  'Nayer',
#  'Redrama',
#  'Kuselofte',
#  'Kaija Koo',
#  'Lenka',
#  'Quavo',
#  'City Girls',
#  'BONES',
#  'Snakehips',
#  'Jessie Reyez',
#  'Felix Jaehn',
#  'Nuorihylly',
#  'iSHi',
#  'Kamatos',
#  'Auntie Hammy',
#  'ibe',
#  'Riton',
#  'Lovespeake',
#  'Doja Cat',
#  'Adam Levine',
#  'Captain Jack',
# ...

# %%
# let's apply our function

# %%
len(get_artists_from_playlist("4rnleEAOdmFAbRcNCgZMpY"))
# Out:
# 2395

# %%
# Copy pasting the above function "get_artists_from_playlist" to rewrite it so that it gives us the artist IDs

def get_artist_ids_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks('spotify', playlist_id)
    
    # should return all the artists
        # but they should be unique! so we make use of set()
    
    return set([artist for subset in [get_artists_ids_from_track(track['track']) for track in tracks_from_playlist] for artist in subset])

# %%
artist_ids = get_artist_ids_from_playlist("4rnleEAOdmFAbRcNCgZMpY")

# %%
len(artist_ids)
# Out:
# 2400

# %% [markdown]
# # 8.05 Activity 3
#
# Iterate over the call (playlist) first 100 tracks to get all the songs ID, name, and artists.
#
# Output: Dictionary with key: song ID and values: list(song name, artist).
#
# iterate over `playlist['items']`
#
#
# ```python
#
# {"2URXBdx9353u9BxBHQoD7K": ["Bohemian Rhapsody", "Queen"],
#  ... ,
#  ... ,
#  ... ,
# }
#
# ```
#
# format:
#
# ```python
# {<song_id> : [<song_name>, <artist_name>],
# <song_id> : [<song_name>, <artist_name>],
# <song_id> : [<song_name>, <artist_name>],
# <song_id> : [<song_name>, <artist_name>],
#  ....
# }
# ```

# %% [markdown]
# # Lab API Wrappers

# %% [markdown]
# Instructions
#
# To move forward with the project, you need to create a collection of songs with their audio features - as large as possible!
#
# These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster. The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.
#
# The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, even hours) to get all the data you need.
#
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!

# %% [markdown]
# Goal:
# Dataframe like this:
#
# song_ID | song_name | artist | danceability | energy | .... | ...
# ---|---|---|---|---|---|---
# value | value |value |value |value |value |value |

# %% [markdown]
# ```python
# >>> sp.audio_features(track_id)[0]
#
# [{'danceability': 0.339,
#   'energy': 0.143,
#   'key': 0,
#   'loudness': -10.78,
#   'mode': 1,
#   'speechiness': 0.0317,
#   'acousticness': 0.921,
#   'instrumentalness': 0.000636,
#   'liveness': 0.372,
#   'valence': 0.0948,
#   'tempo': 101.213,
#   'type': 'audio_features',
#   'id': '74X1epeRufHckhuX1KFD04',
#   'uri': 'spotify:track:74X1epeRufHckhuX1KFD04',
#   'track_href': 'https://api.spotify.com/v1/tracks/74X1epeRufHckhuX1KFD04',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/74X1epeRufHckhuX1KFD04',
#   'duration_ms': 413320,
#   'time_signature': 3}]
# ```

# %% [markdown]
# Documentation [link](https://developer.spotify.com/console/get-audio-features-track/)

# %%
# spotify:playlist:37i9dQZF1DWTcqUzwhNmKv

# %%
get_artists_from_playlist("37i9dQZF1DWTcqUzwhNmKv")
# Out:
# {'Amaranthe',
#  'Amorphis',
#  'Andrew W.K.',
#  'Andy Dörner',
#  'Annisokay',
#  'Architects',
#  'Arion',
#  'Attack Attack!',
#  'Black Veil Brides',
#  'Brand of Sacrifice',
#  'Bring Me The Horizon',
#  'Butcher Babies',
#  'Captives',
#  'Cyan Kicks',
#  'DEAR MOTHER',
#  'Dead by April',
#  'DevilDriver',
#  'Dragged Under',
#  'Dream Drop',
#  'ERRA',
#  'Epica',
#  'Evergrey',
#  'Eyes Set To Kill',
#  'Fight The Fade',
#  'Fit For A King',
#  'Gama Bomb',
#  'Gojira',
#  'HELLYEAH',
#  'Harakiri for the Sky',
#  'Hollow Front',
#  'Hyro The Hero',
#  'Ill Niño',
#  'Imminence',
#  'Islander',
#  'James Labrie',
#  'Keith Wallen',
#  'LANDMVRKS',
#  'Lamb of God',
#  'Love and Death',
#  'Machine Head',
#  'Manafest',
#  'Mike Kerr',
#  'Novelists FR',
#  'Oceans',
#  'Of Mice & Men',
#  'Onlap',
#  'Orchards',
#  'Redlight King',
#  'Rob Zombie',
#  'Ryan Kirby',
#  'Ryo Kinoshita',
#  'Sabaton',
#  'Silver End',
#  'Skywalker',
#  'Soen',
#  'Spiritbox',
#  'Sylosis',
# ...

# %%
user = 'spotify'

playlists = sp.user_playlists(user)
playlist_uri=[]


while playlists:
    for playlist in playlists['items']:
        playlist_uri.append(playlist['uri'])
    if playlists['next']:
        playlists = sp.next(playlists)
    else:
        playlists = None

# %%
len(playlist_uri)
# Out:
# 1396

# %%
from tqdm.notebook import tqdm

# %%
b=get_playlist_tracks('spotify', '37i9dQZF1DXcBWIGoYBM5M')

# %%
b[0]['track']['name']
# Out:
# 'Calling My Phone'

# %%
hamid=[]
lorenz=[]
nico=[]


for playlist in tqdm(playlist_uri):
    
    a=get_playlist_tracks('spotify', playlist)
    
    try:
        for i in tqdm(a):
            hamid.append(i['track']['id'])
            lorenz.append(i['track']['artists'][0]['name'])
            nico.append(i['track']['name'])
    except:
        pass
# Out:
# ...
# ...
# ...

# %%
hamid2=hamid[0:5000]
lorenz2=lorenz[0:5000]
nico2=nico[0:5000]

# %%
import pandas as pd

# %%
data=pd.DataFrame({'id':hamid, 'artist/s':lorenz, 'song_name':nico})

# %%
data.head()

# %%
khurshid=[]
    
for hami in tqdm(hamid2):
    khurshid.append(sp.audio_features(hami))

# %%
import pandas as pd

# %%
data=[]
data=pd.DataFrame(data)
print(type(data))

# %%
len(khurshid)

# %%
for i in khurshid[0]:
    print(i)

# %%
audiof=[]
data = pd.DataFrame(khurshid[0][0].keys())
for i in tqdm(khurshid):
    try:
#         audiof.append(i[0].values())
        data= pd.concat([data,pd.DataFrame(i)], axis=0)
    except:
        pass
data.head()

# %%
khurshid[4]

# %%
# audiof=[]
# data = pd.DataFrame()
# for i in tqdm(khurshid):
#     audiof.append(i[0])
#     data= pd.concat([data,pd.DataFrame(i)], axis=0, ignore_index=True)
# data.head()

# %%
num=data.select_dtypes(include=number)

# %%
num = num.dropna()

# %%
num=pd.DataFrame(num)

# %%
num.head()

# %%
from sklearn.preprocessing import StandardScaler
X_prep = StandardScaler().fit_transform(num)

# %%
X_prep.isna().sum()

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=8, random_state=1234)
kmeans.fit(X_prep)

# print the cluster centers
clusters = kmeans.cluster_centers_

print(clusters)

# %%
clusters = kmeans.predict(X_prep)

# %%
clusters

# %%
pd.Series(clusters).value_counts().sort_index()

# %%
import numpy as np
K = range(2,20)
inertias = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234,
                   )
    kmeans.fit(X_prep)
    inertias.append(kmeans.inertia_)
    
import matplotlib.pyplot as plt

plt.figure(figsize=(16,8))
plt.plot(K, inertias, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title(f'Elbow Method showing the optimal k within {list(K)}')

# %%
from sklearn.metrics import silhouette_score

import numpy as np
K = range(2,20)
silhouettes = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234,
                   )
    kmeans.fit(X_prep)
    silhouettes.append(silhouette_score(X_prep,
                                     kmeans.predict(X_prep)
                                    )
                   )
    
import matplotlib.pyplot as plt

plt.figure(figsize=(16,8))
plt.plot(K, silhouettes, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title(f'Elbow Method showing the optimal k within {list(K)}')

# %%
from yellowbrick.cluster import SilhouetteVisualizer

fig, ax = plt.subplots(2, 2, figsize=(15,8))
for k in [2, 3, 4, 5]:
    '''
    Create KMeans instance for different number of clusters
    '''
    km = KMeans(n_clusters=k,
                random_state=1234)
    q, mod = divmod(k, 2)
    '''
    Create SilhouetteVisualizer instance with KMeans instance
    Fit the visualizer
    '''
    
    visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(X_prep)

# %%
kmeans = KMeans(n_clusters=2,
               random_state=1234)
kmeans.fit(X_prep)

clusters = kmeans.predict(X_prep)

# %%
clusters.shape

# %%
final_df=pd.DataFrame(X_prep, columns=num.columns)

# %%
final_df.head()

# %%
final_df['clusters']=clusters

# %%
final_df.tail()

# %%
len(final_df[final_df['clusters']==1])

# %%
kmeans.cluster_centers_

# %%
cluster_centers_df = pd.DataFrame(kmeans.cluster_centers_, columns=num.columns)

# %%
cluster_centers_df['cluster_id'] = range(0,2)

# %%
cluster_centers_df.head()

# %%
import seaborn as sns

# plot datapoints
sns.scatterplot(data=final_df,
               x="energy",
               y="tempo",
               hue='clusters')

# plot centroids
sns.scatterplot(data=cluster_centers_df,
               x="energy",
               y="tempo",
               hue='cluster_id',
                legend=False,
                marker=u'8',
                s=500,
               )

# %%
for i in final_df.columns:
    sns.distplot(final_df[i])
    plt.show()

# %%
correlations_matrix= final_df.corr()
mask = np.zeros_like(correlations_matrix)
mask[np.triu_indices_from(mask)] = True
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(correlations_matrix, mask=mask, annot=True)
plt.show()

# %%
import random
def my_recommendation(ls):
    guess = str(input('Please Enter your choice of song ')).lower()
    temp = [song for song in ls]
    if guess in temp:
        temp.remove(guess)
        recom = random.choice(temp)
        print('recommended song {}'.format(recom))
    else: 
         print('your choice of song {} is not there!! Sorry'.format(guess))
my_song = list(data['Songs'])
my_recommendation(my_song)
