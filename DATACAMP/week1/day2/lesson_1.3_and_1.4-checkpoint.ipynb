# %%
import pandas as pd

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\lorenzo\appdata\local\programs\python\python39\lib\site-packages (1.2.0)Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 20.3.3 is available.
# You should consider upgrading via the 'c:\users\lorenzo\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: pytz>=2017.3 in c:\users\lorenzo\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2020.5)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\lorenzo\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\lorenzo\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\lorenzo\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
import numpy as np

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\lorenzo\appdata\local\programs\python\python39\lib\site-packages (1.19.5)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 20.3.3 is available.
# You should consider upgrading via the 'c:\users\lorenzo\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %%
# Reading data

# %%
file1 = pd.read_csv('file1python.csv')

# %%
type(file1)
# Out:
# pandas.core.frame.DataFrame

# %%
file1.head()
# Out:
#    CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0     44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1     96093    IL      M    537.0  365  473.0     0  19387      1     89
# 2     43333    FL      F    725.0  301  436.0     3  18837     11     17
# 3     21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4    190108    FL      F    995.0  252  348.0     0  17991      5      6
#
#      IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  430.0  466  28.000000      1  1901     C2     100.0
# 1  415.0  410   5.666667      0     0     T2       7.0
# 2  340.0  361   4.111111      0  2501     C2       5.0
# 3  407.0  399  27.277778      0  2208     T2      38.0
# 4  280.0  316   6.000000     28     0     C2       5.0

# %%
file2 = pd.read_csv('file2python.txt', sep = '\t')

# %%
file2.head()
# Out:
#    CONTROLN STATE   GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  IC2  \
# 0    190579    CA        M  3200  310  343    83  17224     31     32  311
# 1     42997    FL        F  1567  392  409    27  18631      4     10  391
# 2    132896    OR        F   953  319  455     1  15729      3     45  379
# 3    120189    TX        M   492  244  301     3  10818      0     92  260
# 4    138829    AZ  feamale   847  185  308     0  11582      3     20  238
#
#    IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  333   3.106061      1     0     U1       4.0
# 1  434   6.562500      2  1808     C1       7.0
# 2  387  15.571429      2  4410     T1      25.0
# 3  284  19.375000      0     0     T2      25.0
# 4  225  11.500000     28  3601     T2      25.0

# %%
file2.shape
# Out:
# (1015, 17)

# %%
file2.columns
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'DOB', 'DOMAIN',
#        'TARGET_D'],
#       dtype='object')

# %%
pd.read_excel('file3python.xlsx',engine='openpyxl')
# Out:
#      CONTROLN      STATE  GENDER   HV1   IC1   IC4  HVP1    IC5  POBC1  POBC2  \
# 0      119966         TX       F   321   225   281     0   9372      3     68
# 1      152470         CA       F  5725   610   807    97  53158     13     22
# 2       48527         AL    Male   931   407   496     0  17743      0     65
# 3      171528         CA       F  1895   317   471    46  17431     10     62
# 4       50122  Tennessee       F   715   318   370     2  12416      0     75
# 5       92293         IL       F  3359   878   973    87  35266     16     74
# 6       47191         AL       F   950   264   378     3  20090      6     55
# 7       89288         IL       F  1243   414   507     9  15884     18     70
# 8      101676         MO       M  1162   529   612     7  18860      4     60
# 9       30051         GA       F   359   205   292     0   9279      0     90
# 10     141500         NV       M   720   328   381     0  12646      9     19
# 11      21599         SC       M  1168   365   460    15  18128      1     68
# 12     110789         LA       F   324   129   277     1   9585      0     91
# 13     139512         NM       M   828   318   416     2  14887      4     39
# 14     142662         CA       F  1188   166   243     5  10014     10     34
# 15      82920         MN       F   915   469   566     0  17112      4     60
# 16     168186         CA     NaN  2412   549   549    91  16642     17     55
# 17      94503         IL       F   550   157   217     3   6493     16     56
# 18     167406         CA       F  4135   602   694    97  33830      7     60
# 19     170722         CA       F  2043   296   598    52  15530     10     56
# 20     101989         MO       F   523   314   350     0  11799      1     77
# 21      66577         MI       F  2417   575   905    69  34152     17     43
# 22      33003         FL       F   831   242   333     1  19039      5     17
# 23      70216         MI       M   364   312   315     1   9474      3     76
# 24      43086         FL       F   795   352   444     0  18613      6     12
# 25     122110         TX       U   408   254   324     0   8051     15     71
# 26     150684         CA       M  2476   366   537    71  15702     50     38
# 27     162341         CA       F  3693   358   442    97  16753     23     56
# 28      56407         KY       F   382   173   259     0   9037      0     92
# 29     188988         IN     NaN   667   243   351     1  12239      2     70
# 30      35581         FL       M   906   296   473     3  16729      4     37
# 31      46358         FL       M   715   362   408     0  12806      6     28
# 32     109533         LA       M   576   290   375     2   9596      1     66
# 33      81322         WI    male   335   209   311     0   9461      1     88
# 34     179275         WA       F  1424   419   506    21  16767      4     56
# 35      48691         AL       F   733   316   412     0  19790      1     75
# 36      24420         SC       F  1333   162   476    11   4738      2     29
# 37     165368         CA       M  3899   733   811    97  28586     14     49
# 38      41545         FL       M   658   373   436     0  14942     11     23
# 39     106235         KS       M   498   273   346     0  12893      0     69
# 40     133640         ID       M   793   359   505    16  19844      0     45
# 41     176443         OR       F   641   291   391     1  12815      4     45
# 42     190976         AZ     NaN   558   298   345     0  10331      4     33
# 43     145911         CA       F  3314   781   828    99  25608     33     47
# 44      32984         AP    Male     0     0     0     0      0      0      0
# 45      67541         MI       F   558   344   414     0  14032      0     69
# 46      86803         MT  female   419   184   279     1   9682      1     63
# 47     100324         MO       F  1783   577   653    36  26826      0     62
# 48     132444         CO       F   543   428   434     0  12010      1     55
# 49     107235         NE       M  1344   639   758    12  27610      4     53
# 50      67304         MI       F  1335   597   724    24  28770      4     67
# 51      82040         WI    male   493   213   294     1  10815      2     81
# 52      43674         FL       F   888   328   410     0  17342      5     13
# 53     159171         CA       F  1968   416   496    45  16541      9     50
# 54      64400         IN       M  1033   329   473     4  16482     14     47
# 55      11284         FL       M   934   324   478     9  17408      4     11
# 56      74419         MI       F   578   242   328     1  12451      2     83
# 57      55840         MS       M   406   240   265     0   6733      1     61
# 58      22176         NC       M   474   163   253     1  10597      1     73
# 59      25678         FL       M   721   302   365     2  12474      3     51
# 60     107569         NE       M   443   231   323     0  11042      1     79
# 61      70301         MI       F   841   334   462     0  17676      2     79
# 62      39020         FL       M   724   327   371     0  15784     19     25
# 63     125906         TX       F   924   414   438     1  14092      3     55
# 64      23934         SC       F  1056   405   485     5  15432      6     78
# 65     112751         OK       F  1017   672   673     2  18233      0     55
# 66       3651         MI       F   668   300   385     8  14567      3     24
# 67       1068         CA       F  3528   814   867    98  25564     18     43
# 68     120128         TX       F   417   277   326     0  10308      0     89
# 69     152092         CA       F  1232   203   267     1  10129     14     37
# 70      85913         SD       M   396   248   304     1  10419      1     18
# 71      43226         FL       M   764   269   353     1  13439     10      9
# 72      60738         IN       F   877   419   496     0  16981     14     53
# 73      60571         IN       M   696   354   472     3  15493      0     73
# 74     131913         CO       F  1109   513   636     4  20235      0     64
# 75     172140         CA       F  2099   588   643    53  19738      3     66
# 76     147753         CA       F  4778   792   987    95  35530      9     58
# 77     161856         CA       M  2264   430   392    68  16795     13     42
# 78     140611         NM       F   740   240   324     2  10701      9     26
# 79      30068         GA       F   573   250   316     0   9846      1     84
# 246    138944         AZ  Female  1436   298   466    25  20792      9     12
# 247    161204         CA       M   633   269   299     1   9551     12     64
# 248    186579         CA       F  1869   559   600    38  20539      5     61
# 249     11978         CO       M  1213   363   493    19  18860      3     33
# 250    117711         TX       F   271   114   258     0   7545      0     76
# 251     38924         FL       M   740   314   348     0  11579     18     23
# 252     47448         AL    Male   714   324   463     0  16087      3     81
# 253    182479         WA       F   457   259   370     0  12804      4     63
# 254     96075         IL       M   568   220   353     0  12599      0     84
# 255    138997         AZ       M   480   173   235     1   9091      2     21
# 256    108989         LA       F  1381   631   776    19  29012      1     64
# 257     87016         MT  female   425   169   163     0  17618      0     70
# 258     12666         AZ       M   863   274   446     0  22486      4      0
# 259     34302         FL       F   837   321   431     8  13796      3     49
# 260      3018         CA       F  1429   260   329    12   9400     35     44
# 261    145231         CA     NaN     0   303   725     0  33139     22     16
# 262    152418         CA       M  1637   345   454    33  15788      8     46
# 263     65061         MI       M  1559   557   666    27  25181      7     80
# 264     72220         MI       F   835   473   507     2  16227      5     67
# 265    112288         CA       F  1259   389   458    13  15213     10     54
# 266    109539         LA       F   599   271   352     0  11920      0     83
# 267      7836         CA       M  2123   458   539    56  16611     11     49
# 268     41448         FL       F  1503   396   659    29  25969      8     33
# 269    110822         AR  Female   576   284   351     0  10860      1     78
# 270     66163         MI       F   922   448   526     1  20513      2     77
# 271      6183         WA    male  1598   510   568     9  17443      6     42
# 272    124787         TX       F   626   235   272     2   7918     22     68
# 273    109644         FL       J   546   250   270     0  10078      8     27
# 274    105650         KS       F   491   325   356     0  13143      0     74
# 275     45982         FL       F   607   285   362     1  12378      2     29
# 276     14437         CO       M   844   350   393     0  13175      1     49
# 277     10399         NE       F   275   192   338     0  11164      0     89
# 278    151828         CA       M   956   190   303     4   8899     27     44
# 279    162606         CA       F  2653   418   444    86  13440     31     50
# 280    141809         CA       F   788    71   155     0   6409     28     33
# 281    178884         WA    male  1244   418   459     2  14816     10     46
# 282    178098         OR       F   407   186   271     0   9728      1     53
# 283    116082         TX       M   569   328   359     0  11879      6     63
# 284    190769         AR       M   855   257   374     6  14500      1     56
# 285    177087         OR       M   619   372   423     0  13208      0     42
# 286    101654         MO       F   634   322   406     0  14128      1     64
# 287     62760         IN       M   397   297   362     0  11981      1     79
# 288    135406         AZ       M   742   395   441     0  13179      2     36
# 289    142409         NV       M   607   356   431     1  13714      7     26
# 290     79627         WI    male  2083   264   493    52  19012      6     61
# 291     27310         GA       M   866   457   506     0  15079      1     63
# 292    122131         TX       F   831   597   629     0  18705     12     59
# 293    131169         CO       F  1782   537   749    35  28303      5     36
# 294     78009         WI       F   804   426   470     0  14328      2     89
# 295     86445         ND       F   751   304   381     0  13051      1     64
# 296    162343         CA       M  5283   613   742    99  29050     30     50
# 297     35316         FL       F   845   289   436     1  16460     11     20
# 298    148946         CA       F  1756   349   388    18  10285     48     38
# 299      5524         AZ  Female  1084   365   462     2  17575      7     18
# 300     57593         KY       M   310   128   233     0   7656      0     84
# 963   515   552    9.545455      0  5104     U1      11.0
# 964   455   447    7.050000      0  3507     C2       5.0
# 965   361   260    5.777778      2     0     U2       5.0
# 966   631   607   10.733333   1002     0     S1      10.0
# 967   220   216    5.615385      0  3805     R3       7.0
# 968   526   575   11.642857   1002  5809     C1      20.0
# 969   304   279    7.500000      3  4001     T2       8.0
# 970   342   338    6.666667      2     0     T2       6.0
# 971   263   323    4.454545      0  1907     U2      10.0
# 972   470   492   15.000000      0  6401     T2      15.0
# 973   711   756   32.416667      1     0      0      50.0
# 974   240   302   10.545455      1     0      0      10.0
# 975   239   220   15.000000     28     0     S2      15.0
# 976   227   220   15.000000      1  4501     T2      15.0
# 977   259   259   14.720000      2  1804     R2      10.0
# 978   267   299   10.000000     28  1501     S1      12.0
# 979   294   314    7.750000      2     0     T2      15.0
# 980   244   303    9.700000      0  5401     T2      20.0
# 981   174   195    3.250000      1  1401     R3       3.0
# 982   192   204   12.533333      0  5701     T2      20.0
# 983   335   325   13.000000     28     0     T1      25.0
# 984   164   194    4.434783      1  3006     R3       5.0
# 985   768   729   11.000000      0  4704     C1      14.0
# 986   331   321    5.088235      0   712     C2       5.0
# 987   186   252    7.230769      0  2001     C3       5.0
# 988   426   461   12.200000     28  3107     U1      20.0
# 989   252   297   20.000000      0     0     R2      20.0
# 990   395   393   21.666667      0  5108     S2      25.0
# 991   370   392    7.500000      1  2403     S2      10.0
# 992   733   766    7.800000      0  5101     C1      10.0
# 993   516   595    4.277778      2  2101     C1       5.0
# 994   290   333   10.000000      3  6201     T2      15.0
# 995   454   374    9.187500      1  4702     U1      10.0
# 996   286   370   15.100000      0  1701     R1      20.0
# 997   172   232   10.666667     28     0     T3      11.0
# 998   552   552   12.000000     28  5111     T1      25.0
# 999   713   743    9.937500      0  2310     S1      12.0

# %%
file3 = pd.read_excel('file3python.xlsx')

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\lorenzo\appdata\local\programs\python\python39\lib\site-packages (3.0.5)
# Requirement already satisfied: et-xmlfile in c:\users\lorenzo\appdata\local\programs\python\python39\lib\site-packages (from openpyxl) (1.0.1)
# Requirement already satisfied: jdcal in c:\users\lorenzo\appdata\local\programs\python\python39\lib\site-packages (from openpyxl) (1.4.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 20.3.3 is available.
# You should consider upgrading via the 'c:\users\lorenzo\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
file3.head()
# Out:
#    CONTROLN      STATE GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  IC2  \
# 0    119966         TX      F   321  225  281     0   9372      3     68  264
# 1    152470         CA      F  5725  610  807    97  53158     13     22  763
# 2     48527         AL   Male   931  407  496     0  17743      0     65  502
# 3    171528         CA      F  1895  317  471    46  17431     10     62  389
# 4     50122  Tennessee      F   715  318  370     2  12416      0     75  340
#
#    IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  243   8.058824      0  3212     T3      11.0
# 1  698  23.727273      0     0     S1      45.0
# 2  439   4.416667      2     0     R3       3.0
# 3  405   6.705882      0  5501     R2       5.0
# 4  352   9.250000      2     0     T1      10.0

# %%
file4 = pd.read_excel('file4python.xlsx')

# %%
file4.head()
# Out:
#    CONTROLN STATE GENDER      HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  IC2  \
# 0    186307    CA      M  AAA1229  345  438     3  15915      2     58  388
# 1     34174    WV      F      529  198  291     0  10816      0     80  218
# 2    101388    MO      M      526  340  342     0   9687      0     89  348
# 3    159472    CA      F      621  231  279     0   6184     43     41  237
# 4    179143    WA   male     1688  496  564    35  22963      2     63  520
#
#    IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  417  16.142857      1  2511     C2      20.0
# 1  257   6.083333      2  3001     T2      12.0
# 2  321   5.800000      1  5501     R2      10.0
# 3  272  11.666667      1  1512     R3      15.0
# 4  521  23.900000      1  3709     T1      25.0

# %%
column_names = file1.columns

# %%
# blending data

# %%
data = pd.DataFrame(columns=column_names)

# %%
data.head()
# Out:
# Empty DataFrame
# Columns: [CONTROLN, STATE, GENDER, HV1, IC1, IC4, HVP1, IC5, POBC1, POBC2, IC2, IC3, AVGGIFT, TCODE, DOB, DOMAIN, TARGET_D]
# Index: []

# %%
data = pd.concat([data,file1], axis=0)

# %%
data.head()
# Out:
#   CONTROLN STATE GENDER      HV1  IC1    IC4 HVP1    IC5 POBC1 POBC2    IC2  \
# 0    44060    FL      M   AAA896  392  520.0    7  21975     6    16  430.0
# 1    96093    IL      M    537.0  365  473.0    0  19387     1    89  415.0
# 2    43333    FL      F    725.0  301  436.0    3  18837    11    17  340.0
# 3    21885    NC      M  AAA1095  401  413.0    7  14014     1    74  407.0
# 4   190108    FL      F    995.0  252  348.0    0  17991     5     6  280.0
#
#    IC3    AVGGIFT TCODE   DOB DOMAIN  TARGET_D
# 0  466  28.000000     1  1901     C2     100.0
# 1  410   5.666667     0     0     T2       7.0
# 2  361   4.111111     0  2501     C2       5.0
# 3  399  27.277778     0  2208     T2      38.0
# 4  316   6.000000    28     0     C2       5.0

# %%
data = pd.concat([data,file2,file3, file4], axis=0)

# %%
data.shape
# Out:
# (4028, 17)

# %%
# Standardizing header names

# %% [raw]
# Some standards are:
#     use lower case
#     if headers have spaces, replace them with underscores

# %%
cols = []
for i in range(len(data.columns)):
    cols.append(data.columns[i].lower())

# %%
data.columns = cols

# %%
data.head()
# Out:
#   controln state gender      hv1  ic1    ic4 hvp1    ic5 pobc1 pobc2    ic2  \
# 0    44060    FL      M   AAA896  392  520.0    7  21975     6    16  430.0
# 1    96093    IL      M    537.0  365  473.0    0  19387     1    89  415.0
# 2    43333    FL      F    725.0  301  436.0    3  18837    11    17  340.0
# 3    21885    NC      M  AAA1095  401  413.0    7  14014     1    74  407.0
# 4   190108    FL      F    995.0  252  348.0    0  17991     5     6  280.0
#
#    ic3    avggift tcode   dob domain  target_d
# 0  466  28.000000     1  1901     C2     100.0
# 1  410   5.666667     0     0     T2       7.0
# 2  361   4.111111     0  2501     C2       5.0
# 3  399  27.277778     0  2208     T2      38.0
# 4  316   6.000000    28     0     C2       5.0

# %%
data.dtypes
# Out:
# controln     object
# state        object
# gender       object
# hv1          object
# ic1          object
# ic4         float64
# hvp1         object
# ic5          object
# pobc1        object
# pobc2        object
# ic2         float64
# ic3          object
# avggift     float64
# tcode        object
# dob          object
# domain       object
# target_d    float64
# dtype: object

# %%
# deleting columns

# %%
data = data.drop(['tcode', 'domain', 'dob'], axis =1)

# %%
data.head()
# Out:
#   controln state gender      hv1  ic1    ic4 hvp1    ic5 pobc1 pobc2    ic2  \
# 0    44060    FL      M   AAA896  392  520.0    7  21975     6    16  430.0
# 1    96093    IL      M    537.0  365  473.0    0  19387     1    89  415.0
# 2    43333    FL      F    725.0  301  436.0    3  18837    11    17  340.0
# 3    21885    NC      M  AAA1095  401  413.0    7  14014     1    74  407.0
# 4   190108    FL      F    995.0  252  348.0    0  17991     5     6  280.0
#
#    ic3    avggift  target_d
# 0  466  28.000000     100.0
# 1  410   5.666667       7.0
# 2  361   4.111111       5.0
# 3  399  27.277778      38.0
# 4  316   6.000000       5.0

# %%
data.dtypes
# Out:
# controln     object
# state        object
# gender       object
# hv1          object
# ic1          object
# ic4         float64
# hvp1         object
# ic5          object
# pobc1        object
# pobc2        object
# ic2         float64
# ic3          object
# avggift     float64
# target_d    float64
# dtype: object

# %%
data = data.rename(columns={ 'controln':'id','hv1':'median_home_val', 'ic1':'median_household_income'})

# %%
data.head()
# Out:
#        id state gender median_home_val median_household_income    ic4 hvp1  \
# 0   44060    FL      M          AAA896                     392  520.0    7
# 1   96093    IL      M           537.0                     365  473.0    0
# 2   43333    FL      F           725.0                     301  436.0    3
# 3   21885    NC      M         AAA1095                     401  413.0    7
# 4  190108    FL      F           995.0                     252  348.0    0
#
#      ic5 pobc1 pobc2    ic2  ic3    avggift  target_d
# 0  21975     6    16  430.0  466  28.000000     100.0
# 1  19387     1    89  415.0  410   5.666667       7.0
# 2  18837    11    17  340.0  361   4.111111       5.0
# 3  14014     1    74  407.0  399  27.277778      38.0
# 4  17991     5     6  280.0  316   6.000000       5.0

# %%
# Rearranging columns

# %%
data = data[['id', 'state', 'gender', 'median_home_val', 'median_household_income', 'ic2', 'ic3', 'ic4', 'ic5', 'avggift', 'target_d']]

# %%
data.head()
# Out:
#        id state gender median_home_val median_household_income    ic2  ic3  \
# 0   44060    FL      M          AAA896                     392  430.0  466
# 1   96093    IL      M           537.0                     365  415.0  410
# 2   43333    FL      F           725.0                     301  340.0  361
# 3   21885    NC      M         AAA1095                     401  407.0  399
# 4  190108    FL      F           995.0                     252  280.0  316
#
#      ic4    ic5    avggift  target_d
# 0  520.0  21975  28.000000     100.0
# 1  473.0  19387   5.666667       7.0
# 2  436.0  18837   4.111111       5.0
# 3  413.0  14014  27.277778      38.0
# 4  348.0  17991   6.000000       5.0

# %%
# filtering and subsetting -- using conditions with dataframes

# %%
# lets say we ar analyzing data of male donors here

# %%
#data[data['gender']=='M']

# %%
data['gender'].value_counts()
# Out:
# Female    2276
# Male      1625
# U           92
# Name: gender, dtype: int64

# %%
data[data['gender'].isin(['M', 'F'])]
# Out:
# Empty DataFrame
# Columns: [id, state, gender, median_home_val, median_household_income, ic2, ic3, ic4, ic5, avggift, target_d, ic2_]
# Index: []

# %%
# data[(data['gender']=='M') | (data['gender']=='F')]

# %%
# data[(data['gender']=='M') & (data['state']=='FL')]

# %%
# data[data['target_d']>100]

# %%
# data[(data['target_d']<100) & (data['gender']=='F')]

# %% [markdown]
# # Lesson 2

# %%
# working with indexes

# %%
filtered = data[data['gender']=='M']
filtered.head()
# Out:
#        id state gender median_home_val median_household_income    ic2  ic3  \
# 0   44060    FL      M          AAA896                     392  430.0  466
# 1   96093    IL      M           537.0                     365  415.0  410
# 3   21885    NC      M         AAA1095                     401  407.0  399
# 5  100640    IL      M           764.0                     457  477.0  480
# 7  119038    TX      M           890.0                     519  525.0  551
#
#      ic4    ic5    avggift  target_d
# 0  520.0  21975  28.000000     100.0
# 1  473.0  19387   5.666667       7.0
# 3  413.0  14014  27.277778      38.0
# 5  501.0  16022  25.571429      30.0
# 7  560.0  17872   6.175000       7.0

# %%
filtered = filtered.reset_index(drop=True)
filtered.head()
# Out:
#        id state gender median_home_val median_household_income    ic2  ic3  \
# 0   44060    FL      M          AAA896                     392  430.0  466
# 1   96093    IL      M           537.0                     365  415.0  410
# 2   21885    NC      M         AAA1095                     401  407.0  399
# 3  100640    IL      M           764.0                     457  477.0  480
# 4  119038    TX      M           890.0                     519  525.0  551
#
#      ic4    ic5    avggift  target_d
# 0  520.0  21975  28.000000     100.0
# 1  473.0  19387   5.666667       7.0
# 2  413.0  14014  27.277778      38.0
# 3  501.0  16022  25.571429      30.0
# 4  560.0  17872   6.175000       7.0

# %%
# temp = filtered.copy()
# temp.set_index('state') # This is a dummy case but indexes should be unique and not nulls

# %%
filtered[1:4]
# Out:
#        id state gender median_home_val median_household_income    ic2  ic3  \
# 1   96093    IL      M           537.0                     365  415.0  410
# 2   21885    NC      M         AAA1095                     401  407.0  399
# 3  100640    IL      M           764.0                     457  477.0  480
#
#      ic4    ic5    avggift  target_d
# 1  473.0  19387   5.666667       7.0
# 2  413.0  14014  27.277778      38.0
# 3  501.0  16022  25.571429      30.0

# %%
filtered[['gender', 'ic2', 'ic3']][0:10]
# Out:
#   gender    ic2  ic3
# 0      M  430.0  466
# 1      M  415.0  410
# 2      M  407.0  399
# 3      M  477.0  480
# 4      M  525.0  551
# 5      M  458.0  349
# 6      M  588.0  650
# 7      M  260.0  312
# 8      M  168.0  180
# 9      M  317.0  342

# %%
filtered.loc[1:3]
# Out:
#        id state gender median_home_val median_household_income    ic2  ic3  \
# 1   96093    IL      M           537.0                     365  415.0  410
# 2   21885    NC      M         AAA1095                     401  407.0  399
# 3  100640    IL      M           764.0                     457  477.0  480
#
#      ic4    ic5    avggift  target_d
# 1  473.0  19387   5.666667       7.0
# 2  413.0  14014  27.277778      38.0
# 3  501.0  16022  25.571429      30.0

# %%
filtered.loc[100]
# Out:
# id                         124379
# state                          TX
# gender                          M
# median_home_val               308
# median_household_income       161
# ic2                         186.0
# ic3                           204
# ic4                         219.0
# ic5                          6576
# avggift                       4.5
# target_d                      5.0
# Name: 100, dtype: object

# %%
filtered.iloc[1:3] # now i am working just on the indexes row,columns
# Out:
#       id state gender median_home_val median_household_income    ic2  ic3  \
# 1  96093    IL      M           537.0                     365  415.0  410
# 2  21885    NC      M         AAA1095                     401  407.0  399
#
#      ic4    ic5    avggift  target_d
# 1  473.0  19387   5.666667       7.0
# 2  413.0  14014  27.277778      38.0

# %%
filtered.iloc[1:10,0:4]
# Out:
#        id state gender median_home_val
# 1   96093    IL      M           537.0
# 2   21885    NC      M         AAA1095
# 3  100640    IL      M           764.0
# 4  119038    TX      M           890.0
# 5   87259    MT      M             717
# 6  115823    TX      M            1011
# 7   95701    IL      M            1063
# 8    5172    IL      M             291
# 9  152486    CA      M            1538

# %%
filtered.dtypes
# Out:
# id                          object
# state                       object
# gender                      object
# median_home_val             object
# median_household_income     object
# ic2                        float64
# ic3                         object
# ic4                        float64
# ic5                         object
# avggift                    float64
# target_d                   float64
# dtype: object

# %%
filtered[1:3]
# Out:
#       id state gender median_home_val median_household_income    ic2  ic3  \
# 1  96093    IL      M           537.0                     365  415.0  410
# 2  21885    NC      M         AAA1095                     401  407.0  399
#
#      ic4    ic5    avggift  target_d
# 1  473.0  19387   5.666667       7.0
# 2  413.0  14014  27.277778      38.0

# %%
filtered.iloc[[1,2,3,4],[0,2,4]]
# Out:
#        id gender median_household_income
# 1   96093      M                     365
# 2   21885      M                     401
# 3  100640      M                     457
# 4  119038      M                     519

# %%
filtered.iloc[[1,2,3,4],[0,2,4]]
# Out:
#        id gender median_household_income
# 1   96093      M                     365
# 2   21885      M                     401
# 3  100640      M                     457
# 4  119038      M                     519

# %%
# data types

# %%
data.dtypes
# Out:
# id                          object
# state                       object
# gender                      object
# median_home_val             object
# median_household_income     object
# ic2                        float64
# ic3                         object
# ic4                        float64
# ic5                         object
# avggift                    float64
# target_d                   float64
# dtype: object

# %%
# data._get_numeric_data()

# %%
# data._get_bool_data()

# %%
# data.select_dtypes('object')

# %%
c # Creating a copy before we start with data cleaning process

# %%
# temp['median_home_val'] = temp['median_home_val'].astype('float', errors='ignore')
# temp.dtypes

# as you would see astype() does not work well here because some elements in the series are strings

# %%
data['median_home_val'] =  pd.to_numeric(data['median_home_val'], errors='coerce')
data['median_household_income'] =  pd.to_numeric(data['median_household_income'], errors='coerce')
data['ic5'] =  pd.to_numeric(data['ic5'], errors='coerce')
data.dtypes
# It replaces the values that are not floats to NaNs
# Out:
# id                          object
# state                       object
# gender                      object
# median_home_val            float64
# median_household_income      int64
# ic2                        float64
# ic3                         object
# ic4                        float64
# ic5                        float64
# avggift                    float64
# target_d                   float64
# dtype: object

# %%
# Removing duplicates

# %%
print(data.shape)
data = data.drop_duplicates()
print(data.shape)
# Out:
# (4028, 11)
# (4001, 11)

# %%
# temp = temp.drop_duplicates(subset=['state','gender', 'ic2', 'ic3'])
# if we want to remove duplicates based on some specific columns

# %% [markdown]
# # Next code is for section 1.04

# %% [markdown]
# # Lesson 1

# %% [raw]
# Dropping columns with more null values
# Replacing / imputing null values
# Removing outliers

# %%
# data.isna().sum()
# data.isna().sum()/len(data)
round(data.isna().sum()/len(data),4)*100  # shows the percentage of null values in a column
# Out:
# id                         0.00
# state                      0.00
# gender                     3.32
# median_home_val            0.25
# median_household_income    0.00
# ic2                        0.02
# ic3                        0.00
# ic4                        0.02
# ic5                        0.15
# avggift                    0.00
# target_d                   0.00
# dtype: float64

# %%
# dropping columns with more null values -- analyst decides the threshold value

# note that the threshold values are usually higher percentages, for eg if 70% or more
# values in a column are missing, then its a good idea to drop those columns

# %%
nulls_df = pd.DataFrame(round(data.isna().sum()/len(data),4)*100)
nulls_df = nulls_df.reset_index()
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                 header_name  percent_nulls
# 0                        id           0.00
# 1                     state           0.00
# 2                    gender           3.32
# 3           median_home_val           0.25
# 4   median_household_income           0.00
# 5                       ic2           0.02
# 6                       ic3           0.00
# 7                       ic4           0.02
# 8                       ic5           0.15
# 9                   avggift           0.00
# 10                 target_d           0.00

# %%
columns_drop = nulls_df[nulls_df['percent_nulls']>3]['header_name']  # dummy case with 3 
print(columns_drop.values)
# Out:
# ['gender']

# %%
# data = data.drop(columns_drop, axis=1)
# data = data.drop(['gender'], axis=1)

# %%
# Replacing / imputing null values

# %%
# Numerical columns: Some ways to approach the problem

# Ignore these observations
# Replace with general average
# Replace with similar type of averages
# Build model to predict missing values

# %%
# if you have sufficient data and losing a few rows of data is not too bad, you can filter those
# rows out as well

# %%
data[data['gender'].isna()==True] # checking rows that are null based on a specific column
# Out:
#          id       state gender  median_home_val  median_household_income  \
# 15    73699          MI    NaN            890.0                      463
# 21   114721          OK    NaN           1040.0                      472
# 22   111795          AR    NaN            603.0                      208
# 54   190671          CA    NaN           2143.0                      280
# 77   156324        Cali    NaN           2016.0                      431
# 84    60512          IL    NaN           1055.0                      366
# 94    37118          FL    NaN            581.0                      349
# 130   35276          FL    NaN           3542.0                      642
# 151  156568          CA    NaN           3020.0                      756
# 186  187571          IN    NaN            561.0                      302
# 195   41715          FL    NaN            696.0                      272
# 217    8240          CA    NaN           1187.0                      328
# 239  188164          TX    NaN           1362.0                      575
# 345  187298          SC    NaN           1015.0                      478
# 353  149626          NV    NaN           1557.0                      290
# 374  153450  California    NaN           1865.0                      256
# 406  169780  California    NaN           1650.0                      219
# 420  148998  California    NaN           3233.0                      684
# 445  178826          CO    NaN            872.0                      418
# 470  142057          NV    NaN           2479.0                      409
# 489  148354  California    NaN           2206.0                      574
# 495  165302  California    NaN           2811.0                      524
# 521  130756          CO    NaN           2408.0                      906
# 522   87281          MT    NaN            445.0                      192
# 524   20065          NC    NaN            722.0                      327
# 594  188035          AZ    NaN           1165.0                      489
# 624  130684          AL    NaN           1175.0                      586
# 669  169605  California    NaN           1185.0                      338
# 670  157573  California    NaN           2438.0                      540
# 682  146703  California    NaN            675.0                      172
# 720  114676          OK    NaN           1062.0                      486
# 740  113045          OK    NaN            699.0                      393
# 786     263          SC    NaN           2156.0                      331
# 819  185760          GA    NaN            659.0                      250
# 869  175438          OR    NaN            925.0                      129
# 870   68427          MI    NaN            483.0                      341
# 895   10893          CA    NaN           2012.0                      225
# 964   63000          IN    NaN            351.0                      192
# 986   27846          GA    NaN           1149.0                      420
# 10   167039          CA    NaN           3201.0                      497
# 12   151653          CA    NaN           1455.0                      376
# 30   179377          WA    NaN           1617.0                      398
# 103   74701          MI    NaN            360.0                      206
# 114  151455          CA    NaN           2105.0                      301
# 119   91965          IL    NaN           1708.0                      342
# 144   10709          WA    NaN            534.0                      206
# 148  187191          GA    NaN           2639.0                      436
# 152  163369          CA    NaN           2250.0                      181
# 164    2396          FL    NaN            588.0                      233
# 181   40351          FL    NaN           1074.0                      505
# 182   43321          FL    NaN           1452.0                      352
# 209  120608          TX    NaN            375.0                      182
# 237   21107          NC    NaN            678.0                      260
# 296   77742          TX    NaN           1163.0                      378
# 410  133176          ID    NaN           2111.0                      320
# 432  158567          CA    NaN           1722.0                      324
# 444  184269          WA    NaN            506.0                      274
# 511   28082          GA    NaN           1063.0                      477
# 549  115676          TX    NaN            340.0                      191
# 639   45551          FL    NaN              0.0                        0
# 660  187764     Arizona    NaN           1553.0                      634
# 705   75461          IA    NaN            221.0                      216
# 736   83530          MN    NaN            656.0                      272
# 765   26378          GA    NaN           1153.0                      562
# 802   16247          NC    NaN            576.0                      289
# 830   18038          NC    NaN            548.0                      197
# 989  105371          KS    NaN            208.0                      201
# 16   168186          CA    NaN           2412.0                      549
# 29   188988          IN    NaN            667.0                      243
# 42   190976          AZ    NaN            558.0                      298
# 84    54897          GA    NaN           1271.0                      733
# 99   188141          FL    NaN            578.0                      248
# 168  136772          AZ    NaN            801.0                      349
# 196  157481          CA    NaN           2439.0                      521
# 203  163675          CA    NaN           1693.0                      423
# 207  187959          NC    NaN           1024.0                      360
# 243  118367          TX    NaN            462.0                      214
# 261  145231          CA    NaN              0.0                      303
# 348  123669          TX    NaN            923.0                      554
# 376  172359          CA    NaN            566.0                      208
# 387  191531          CA    NaN           1073.0                      359
# 418  190634          SC    NaN            834.0                      389
# 457  190412          CO    NaN           1956.0                      768
# 474  177458          OR    NaN            573.0                      150
# 513  111045          AR    NaN            428.0                      208
# 518   49109          AL    NaN            394.0                      248
# 559   77379          WI    NaN            789.0                      415
# 564   36576          FL    NaN           1342.0                      472
# 591  133948          CA    NaN           2170.0                      397
# 627  177009          OR    NaN            584.0                      262
# 637  181998          WA    NaN           1222.0                      423
# 650    8742          CO    NaN            591.0                      211
# 660  164796          CA    NaN           3692.0                      783
# 675  171677          CA    NaN           1375.0                       92
# 715  134677          UT    NaN            684.0                      345
# 794  183412          WA    NaN            383.0                      178
# 820   22645          SC    NaN            416.0                      191
# 839  140294          NM    NaN            697.0                      197
# 882  115094          OK    NaN            521.0                      249
# 891  155040          CA    NaN           1382.0                      316
# 927   69536          MI    NaN            394.0                      228
# 947  138000          AZ    NaN            630.0                      222
# 989  173744          HI    NaN            798.0                      234
# 6    135983          AZ    NaN            638.0                      213
# 48    73371          MI    NaN            363.0                      256
# 117    2691          NV    NaN            834.0                      260
# 150  155114          CA    NaN           1176.0                      251
# 175    7451          SC    NaN            608.0                      229
# 181    1685          CA    NaN           1130.0                      333
# 185  143011          CA    NaN           5727.0                      694
# 189  188778          FL    NaN            635.0                      225
# 201  190408          FL    NaN              NaN                      255
# 205  188054          CA    NaN           2176.0                      419
# 226  187748          FL    NaN            865.0                      341
# 284  156618          CA    NaN           2043.0                      364
# 304   75835          IA    NaN            298.0                      234
# 305    4606          IL    NaN           1045.0                      288
# 318   90894          IL    NaN            827.0                      369
# 345   89210          AR    NaN            493.0                      188
# 354  127108          TX    NaN            727.0                      427
# 426  170714          CA    NaN           1452.0                      286
# 445  131468          CO    NaN            726.0                      303
# 475   67961          MI    NaN            355.0                      293
# 527    6851          CA    NaN           1400.0                      246
# 543  182895          WA    NaN            563.0                      340
# 989   252.0  297  321.0  10082.0  20.000000      20.0
# 6     236.0  220  226.0   9836.0   4.652174       7.0
# 48    298.0  288  331.0  12080.0   5.125000      10.0
# 117   311.0  297  340.0  13687.0  10.250000      16.0
# 150   314.0  308  373.0  13924.0   9.111111      14.0
# 175   350.0  268  362.0  13829.0  14.823529      22.0
# 181   383.0  385  431.0  15654.0  14.000000      20.0
# 185  1051.0  826  981.0  47422.0   5.346154       5.0
# 189   248.0  269  291.0  10611.0  13.250000      20.0
# 201   273.0  294  331.0  13727.0   6.600000       7.0
# 205   453.0  461  483.0  14484.0   7.076923      13.0
# 226   387.0  392  432.0  15630.0   8.375000       7.0
# 284   385.0  412  423.0  19087.0   9.666667      25.0
# 304   250.0  269  279.0   9825.0   3.857143       5.0
# 305   347.0  337  399.0  12829.0  24.750000      25.0
# 318   415.0  386  430.0  14536.0   4.473684       4.0
# 345   202.0  223  259.0   9997.0  44.727273      25.0
# 354   421.0  431  437.0  14147.0  13.750000      10.0
# 426   279.0  346  363.0  13126.0  12.615385      20.0
# 445   321.0  362  400.0  15904.0   7.363636       8.0
# 475   312.0  312  320.0  11403.0  15.000000      21.0
# 527   304.0  281  331.0  11924.0  10.000000       7.0
# 543   430.0  366  414.0  13688.0   4.941176      10.0
# 671   463.0  476  519.0  16290.0   8.571429       9.0
# 737   357.0  378  431.0  13352.0   7.400000      10.0
# 758     0.0  601    0.0  14633.0  10.962963      15.0
# 790   593.0  521  628.0  22094.0   5.300000      11.0
# 860   464.0  493  507.0  18693.0  10.285714      19.0
# 894   258.0  286  326.0  13218.0  10.750000      15.0
# 946   463.0  403  527.0  23732.0  15.000000      25.0
# 966   236.0  253  288.0  11547.0   7.320000       5.0

# %%
data = data[data['ic2'].isna()==False] # Since these nulls are not a lot, we can filter them 
data = data[data['ic4'].isna()==False]
data = data[data['ic5'].isna()==False]

# %%
mean_median_home_value = np.mean(data['median_home_val'])
data['median_home_val'] = data['median_home_val'].fillna(mean_median_home_value)

# %%
data.head()
# Out:
#        id state gender  median_home_val  median_household_income    ic2  ic3  \
# 0   44060    FL      M      1158.437751                      392  430.0  466
# 1   96093    IL      M       537.000000                      365  415.0  410
# 2   43333    FL      F       725.000000                      301  340.0  361
# 3   21885    NC      M      1158.437751                      401  407.0  399
# 4  190108    FL      F       995.000000                      252  280.0  316
#
#      ic4      ic5    avggift  target_d
# 0  520.0  21975.0  28.000000     100.0
# 1  473.0  19387.0   5.666667       7.0
# 2  436.0  18837.0   4.111111       5.0
# 3  413.0  14014.0  27.277778      38.0
# 4  348.0  17991.0   6.000000       5.0

# %% [markdown]
# # Lesson 2

# %%
# Replacing null values for categorical variables 

# General Approaches:
    
# Ignore observation
# Replace by most frequent value
# Replace using an algorithm like KNN using the neighbours.
# Predict the observation using a multiclass predictor.
# Treat missing data as just another category

data['gender'].value_counts()
# Out:
# F          1947
# M          1466
# male        126
# female      106
# Female       75
# U            68
# Male         33
# J            23
# feamale      15
# A             1
# Name: gender, dtype: int64

# %%
len(data[data['gender'].isna()==True])  # number of missing values
# Out:
# 133

# %%
data['gender'] = data['gender'].fillna('F')

# %%
# Removing outliers

# %%
# This is done using a box plot which we will cover later 
# After identifying the upper limit and the lower limit values for a numerical column
# we can use filters to remove those rows from the dataframe

# %%
# Exporting this processed data to a csv

# %%
data.to_csv('merged_clean_ver1.csv')

# %% [raw]
# Creating lambda expressions
# Creating map functions on columns in dataframes

# %%
y = lambda x: x+2

# %%
y(2)
# Out:
# 4

# %%
square = lambda x: x*x
square(4)
# Out:
# 16

# %%
addition = lambda x,y : x+y
addition(1,3)
# Out:
# 4

# %%
lst = [1,2,3,4,5,6,7,8,10]
new_list = []
for item in lst:
    new_list.append(square(item))
new_list
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 100]

# %%
new_list = [square(item) for item in lst] # list comprehension
new_list
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 100]

# %%
new_list = []
for item in lst:
    if item %2 ==0:
        new_list.append(square(item))
new_list
# Out:
# [4, 16, 36, 64, 100]

# %%
new_list = [square(item) for item in lst if item%2==0]
new_list
# Out:
# [4, 16, 36, 64, 100]

# %% [markdown]
# # Lesson 3

# %%
data.columns = list(map(lambda x: x.lower(), data.columns))

# %%
data.dtypes
# Out:
# id                          object
# state                       object
# gender                      object
# median_home_val            float64
# median_household_income      int64
# ic2                        float64
# ic3                         object
# ic4                        float64
# ic5                        float64
# avggift                    float64
# target_d                   float64
# dtype: object

# %%
# data['gender'] = list(map(lambda x: x.upper(), data['gender'])) 
# This will give you an error. So you have to remove rows where gender is empty

# %%
data['gender'].unique() # check the unique values in the column
# Out:
# array(['M', 'F', 'female', 'Male', 'U', 'J', 'male', 'Female', 'feamale',
#        'A'], dtype=object)

# %%
data['gender'] = list(map(lambda x: x.upper(), data['gender']))

# %%
# Cleaning column gender using map function and another user defined function

# %%
def clean(x):
    if x in ['M', 'MALE']:
        return 'Male'
    elif x.startswith('F'):
        return 'Female'
    else:
        return 'U'

# %%
data['gender'] = list(map(clean, data['gender']))

# %%
data['gender'].unique()
# Out:
# array(['Male', 'Female', 'U'], dtype=object)

# %%
# Creating buckets / groups of data

# %%
ic2_labels = ['Low', 'Moderate', 'High', 'Very High']
data['ic2_'] = pd.cut(data['ic2'],4, labels=ic2_labels)
# there is also pd.qcut which is based on quantiles. We will discuss it later

# %%
# pd.cut(data['ic2'],4) # to check the bins

# %%
# For cities create a user defined function and use it with map()
# to divide the cities into 5 zones - East, west, north, south, and central

# %% [markdown]
# # Lesson 4

# %% [raw]
# Working with datetime format
# Standardizing input
# Using string functions

# %%
file = pd.read_csv('/Users/himanshuaggarwal/ironhack-my-content/datasets_for_wrangling/ab_testing_case_study/df_final_web_data_pt_1.csv')
file.dtypes
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-203-cea44f9931d6> in <module>
# ----> 1 file = pd.read_csv('/Users/himanshuaggarwal/ironhack-my-content/datasets_for_wrangling/ab_testing_case_study/df_final_web_data_pt_1.csv')
#       2 file.dtypes
#
# c:\users\lorenzo\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# --> 605     return _read(filepath_or_buffer, kwds)
#     606
#     607
#
# c:\users\lorenzo\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(filepath_or_buffer, **kwds)
#     458
#     459     if chunksize or iterator:
#
# c:\users\lorenzo\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     812             self.options["has_index_names"] = kwds["has_index_names"]
#     813
# --> 814         self._engine = self._make_engine(self.engine)
#     815
#     816     def close(self):
#
# c:\users\lorenzo\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1043             )
#    1044         # error: Too many arguments for "ParserBase"
# -> 1045         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1046
#    1047     def _failover_to_python(self):
#
# c:\users\lorenzo\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1860
#    1861         # open handles
# -> 1862         self._open_handles(src, kwds)
#    1863         assert self.handles is not None
#    1864         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# c:\users\lorenzo\appdata\local\programs\python\python39\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1355         Let the readers open IOHanldes after they are done with their potential raises.
#    1356         """
# -> 1357         self.handles = get_handle(
#    1358             src,
#    1359             "r",
#
# c:\users\lorenzo\appdata\local\programs\python\python39\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     637         if ioargs.encoding and "b" not in ioargs.mode:
#     638             # Encoding
# --> 639             handle = open(
#     640                 handle,
#     641                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/himanshuaggarwal/ironhack-my-content/datasets_for_wrangling/ab_testing_case_study/df_final_web_data_pt_1.csv'

# %%
file.head(3)

# %%
file['date_time'] = pd.to_datetime(file['date_time'], errors='coerce')

# %%
file.head(3)

# %%
file['date_time'][0].day
file['date_time'][0].month
file['date_time'][0].year
file['date_time'][0].isoweekday()  # Returns 1 for Monday and so on

# %%
file['date_time'][0].time()

# %%
file['date_time'][0].isoweekday()

# %%
file['date_time'][0].isoformat()

# %%
file['date_time'][0].strftime(format='%d-%M-%Y')

# %%
file['date_time'][0].strftime(format="%A %d. %B %Y")

# %% [raw]
# https://docs.python.org/3/library/time.html
#
# Directive and their Meaning
#
# %a Locale’s abbreviated weekday name.
# %A Locale’s full weekday name.
# %b Locale’s abbreviated month name.
# %B Locale’s full month name.
# %c Locale’s appropriate date and time representation.
# %d Day of the month as a decimal number [01,31].
# %H Hour (24-hour clock) as a decimal number [00,23].
# %I Hour (12-hour clock) as a decimal number [01,12].
# %j Day of the year as a decimal number [001,366].
# %m Month as a decimal number [01,12].
# %M Minute as a decimal number [00,59].
# %p Locale’s equivalent of either AM or PM.
# %S Second as a decimal number [00,61].
# %U Week number of the year (Sunday as the first day of the week) as a decimal number [00,53]. All days in a new year preceding the first Sunday are considered to be in week 0.
# %w Weekday as a decimal number [0(Sunday),6].
# %W Week number of the year (Monday as the first day of the week) as a decimal number [00,53]. All days in a new year preceding the first Monday are considered to be in week 0
# %x Locale’s appropriate date representation.
# %X Locale’s appropriate time representation.
# %y Year without century as a decimal number [00,99].
# %Y Year with century as a decimal number.
# %z Time zone offset indicating a positive or negative time difference from UTC/GMT of the form +HHMM or -HHMM, where H represents decimal hour digits and M represents decimal minute digits [-23:59, +23:59].
# %Z Time zone name (no characters if no time zone exists).
# %% A literal '%' character.

# %%
import time
from datetime import date
today = date.today()
today

# %%
import time
time.time() # time in seconds

# %%
time.localtime(time.time())

# %%
time.gmtime(time.time())

# %%
# String functions

# %%
# https://docs.python.org/2.5/lib/string-methods.html

# %%
string = " I am learning  data  analysis at Ironhack  . It is  super easy "
string.lower()
string.upper()

# %%
'34'.isdigit() # does not work with decimal numbers

# %%
string.lstrip()
string.rstrip()
string.split()
string.split('.')

# %%
string.replace('  ', ' ')
